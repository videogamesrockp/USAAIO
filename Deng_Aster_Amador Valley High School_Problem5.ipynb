# %% [markdown]
# # **Starter code**

# %%
# Paste the starter code provided in this problem. Run it.
# !pip install gensim
import gensim.downloader as api
from gensim.utils import simple_preprocess
import requests

import numpy as np
import matplotlib.pyplot as plt

url_part1 = "https://huggingface.co/datasets/usaaio-official/"
glove = api.load("glove-wiki-gigaword-100")

url_part2 = "2026_USAAIO_Round1_public/raw/main/"
url_part3 = "2026_USAAIO_Round1_NLP.txt"
url = url_part1 + url_part2 + url_part3

text = requests.get(url).text

tokens = simple_preprocess(text)
tokens = [token for token in tokens if token in glove]
print(len(tokens))
tokens = list(set(tokens))
print(len(tokens))
vectors = [glove[word] for word in tokens]
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# [==================================================] 100.0% 128.1/128.1MB downloaded
# 225
# 158

# %% [markdown]
# # **Problem 5, Part 1**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
# Because the tokens aren't all unique so when we convert it to a set and into a list it removed duplicates, therefore giving us a smaller size.
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 2**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
# It converts the tokens into a set, thus removing duplicates, and then converts it back into a list.
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 3**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 5, Part 4**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 5, Part 5**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 6**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 7**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 5, Part 8**

# %% [markdown]
# **Part 8.1 (coding task)**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# **Part 8.2 (non-coding task)**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 9**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 5, Part 10**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 11**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 5, Part 12**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 5, Part 13**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 14**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 15**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """
