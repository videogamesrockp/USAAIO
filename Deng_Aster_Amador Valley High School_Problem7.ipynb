# %% [markdown]
# # **Starter code**

# %%
# Paste the starter code provided in this problem. Run it.

import torch
import torch.nn as nn

# %% [markdown]
# # **Problem 7, Part 1**

# %%
### WRITE YOUR SOLUTION HERE ###
class My_Threshold(nn.Module):
  def __init__(self):
    super().__init__()

  def forward(self, x):
    x = (x >= 0).type(torch.float)
    return x

""" END OF THIS PART """
# Out:
# tensor([1., 1., 1.])
# ' END OF THIS PART '

# %% [markdown]
# # **Problem 7, Part 2**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
# The variance of y, $\mathrm{Var}[y] $, can be written in terms of the variances of $w_c$ and $x_c$ as
#
# $$
# \mathrm{Var}[y] = \mathrm{Var}[w_c] \mathrm{Var}[x_c]
# $$
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 7, Part 3**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 7, Part 4**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """
